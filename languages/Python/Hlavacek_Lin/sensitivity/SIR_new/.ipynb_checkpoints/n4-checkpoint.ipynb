# %%
import numpy as np
from scipy.integrate import solve_ivp
from scipy.optimize import minimize
import matplotlib.pyplot as plt
newCases = np.genfromtxt('model.txt')[:,1]
totalN = len(newCases)
tSpan = np.linspace(0, totalN-1, totalN)
t0, t1, t2, t3, b0, b1, b2, b3, g, i0, m = 2, 4, 87, 92, 4.6e-2, 7.8e-3, 7.8e-2, 2.6e-4, 0.02, 0.0023, 1700
par = np.array([t0, t1, t2, t3, b0, b1, b2, b3, g, i0, m])
s0, i0, r0 = 1, i0, 0
s, i, r = s0, i0, r0
IC = state = np.array([s,i,r])
stateDim, parDim = len(IC), len(par)
def F(t,state,par):
    s, i, r = state
    t0, t1, t2, t3, b0, b1, b2, b3, g, i0, m = par
    if t <= t0:
        b = 0
    elif t <= t0 + t1:
        b = b0
    elif t <= t0 + t1 + t2:
        b = b1
    elif t <= t0 + t1 + t2 + t3:
        b = b2
    else:
        b = b3
    return np.array([-b*s*i,b*s*i-g*i,g*i])
def process(par):
    sol = solve_ivp(fun=lambda t,z: F(t,z,par), t_span=(tSpan[0],tSpan[-1]),y0=state, t_eval=tSpan, method='RK45',rtol=1e-6,atol=1e-6)
    newCases = par[-1]*sol.y[1,:]
    return newCases
def penalty(par):
    output = process(par)
    Lval = np.sum((output-newCases)**2)
    return Lval        

bds = np.array([[1e-6,1e2],[1e-6,1e2],[1e-6,1e2],[1e-6,1e2],[1e-6,1e0],[1e-6,1e0],[1e-6,1e0],[1e-6,1e0],[1e-6,1e0],[1e-6,1e0],[1e0,1e4]])
x0 = par
result = minimize(penalty, x0, method='Nelder-Mead', options={'adaptive': True, 'disp': True, 'maxiter': 10000, 'maxfev': 10000}, bounds = bds)
# Out:
# Optimization terminated successfully.
#          Current function value: 5152.678759
#          Iterations: 5741
#          Function evaluations: 9482

# %%
plt.rcParams.update({'font.size':12})
fig = plt.figure()
fig.set_size_inches(9,9)
ax = plt.subplot(1,1,1)
ax.scatter(tSpan, newCases, 60, marker='+', color = 'black', zorder = 500)
ax.plot(tSpan,process(result.x), color='red', linewidth = 2)           
ax.set_xticks(np.linspace(0,len(newCases)-1,12))
ax.set_xticklabels(['09-01-22','09-23-22','10-15-22','11-06-22','11-28-22','12-20-22','01-11-23','02-02-23','02-24-23','03-18-23','04-09-23','04-30-23'],rotation=90)
ax.set_ylabel('Confirmed hospitalization counts')
ax.set_title('Nevada')
plt.savefig('/Users/amallela/Documents/sensitivity/writing/p0.pdf',dpi=600)

# %%
result.x
# Out:
# array([1.80284887e+00, 3.57625772e+00, 3.31419555e+01, 5.25991957e+01,
#        3.89067954e-02, 1.84218192e-02, 1.44012939e-01, 1.81989818e-04,
#        4.50098954e-02, 2.33664779e-03, 5.87775792e+02])

# %%
result.fun
# Out:
# 5152.6787587472845

# %%
len(newCases)
# Out:
# 242
